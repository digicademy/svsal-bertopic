# %%
import pandas as pd
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

df = pd.read_csv('/Users/jessicacarrillo/Praxisprojekt/Daten/verarbeitete_Daten/Latein/LAT_+Stopwords/lat_gefilterte_topics.csv', header=None)
docs_lat = df.apply(lambda row: ' '.join(map(str, row)), axis=1).tolist()

zeroshot_topic_list = ["Bellum", "Actio", "Electio","Depositum", "Iniuria", "Procurator", "Privilegium", "Suspensio", "Usura", "Consilium", "Confessio", "Dignitas"]

# We fit our model using the zero-shot topics
# and we define a minimum similarity. For each document,
# if the similarity does not exceed that value, it will be used
# for clustering instead.
topic_model = BERTopic(
    embedding_model="thenlper/gte-small", 
    min_topic_size=20,
    zeroshot_topic_list=zeroshot_topic_list,
    zeroshot_min_similarity=.300,
    representation_model=KeyBERTInspired()
)
topics, _ = topic_model.fit_transform(docs_lat)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
topic_model.get_topic_info()
# Out:
#     Topic  Count         Name  \
# 0       0     68    Depositum
# 1       1     63    Confessio
# 2       2     41  Privilegium
# 3       3     24    Suspensio
# 4       4     16       Bellum
# 5       5     15     Dignitas
# 6       6     11    Consilium
# 7       7      9        Actio
# 8       8      4   Procurator
# 9       9      3      Iniuria
# 10     10      1      Electio
#
#                                                                                                                             Representation  \
# 0                                    [sententia, restitutionem, contractus, ecclesiae, pactum, illius, huius, dict, secundum, emphyteusis]
# 1                                                     [testamentum, sententia, secundum, verba, causa, papa, consilio, eius, en, probatur]
# 2                                                 [gentium, genus, dominium, eius, ecclesiae, solum, priuilegium, fructus, vsum, consilio]
# ...
